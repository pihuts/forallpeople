# %%
import forallpeople as si
si.environment('structural', top_level=True)
si.environment.auto_prefix = False
# Test case 1: Length
m = si.m
val = 5000 * m
print(f"5000 * m = {val}")

# Test case 2: Current
A = si.A
curr = 0.5 * A
print(f"0.5 * A = {curr}")
# Out:
# 5000 * m = 5000.000 m
# 0.5 * A = 0.500 A

# %%
km/m
# Out:
# 1000.0

# %%
kPa
# Out:
# 1.000 kPa

# %%
L
# Out:
# 1.000 L

# %%
mL.to("m3")
# Out:
# 0.000 m³

# %%
(mm**3).to('mL')
# Out:
# 0.001 mL

# %%
mm.to("m")
# Out:
# 0.001 m

# %%
day/s
# Out:
# 86400.0

# %%
minute/s
# Out:
# 60.0

# %%
m/mm
# Out:
# 1000.0

# %%
import forallpeople
import sys
print("File:", forallpeople.__file__)
si.environment('structural')
if hasattr(si, 'km'):
    print("km factor:", si.km.factor)
else:
    print("km not found")
# Out:
# File: c:\Users\peter\OneDrive\Documents\forallpeople\forallpeople\__init__.py
# km factor: 1000

# %%
si.km.value
# Out:
# 1000.0

# %%
print("L factor:", si.L.factor)
# Out:
# L factor: 1/1000

# %%
si.km/si.m
# Out:
# 1000.0

# %%
km.to("cm")
# Out:
# 100000.000 cm

# %%
a = 106.73*kN/m**3
b = 280 * mm
c = a*b
c.to("kPa")
# Out:
# 29.884 kPa

# %%
from ipython import display,latex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from ipython import display,latex
#
# ModuleNotFoundError: No module named 'ipython'

# %%
(kN/mm**2).to("kN_mm2")
# Out:
# 1.000 kN/mm²

# %%
(70*mm).to('m')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 (70*mm).to('m')
#
# NameError: name 'mm' is not defined

# %%
(m*mm**2).to("m3")
# Out:
# 0.000 m³
